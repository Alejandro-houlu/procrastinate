# %%
import pandas as pd
import os
from pathlib import Path
import re
from wordcloud import WordCloud
import gensim
from gensim.utils import simple_preprocess
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
import gensim.corpora as corpora
from pprint import pprint
import pyLDAvis.gensim
import pickle
import pyLDAvis
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
from datasets.load import requests
from pypdf import PdfReader
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/alejandro/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# 2024-04-22 17:43:19,223 : INFO : PyTorch version 2.2.1 available.

# %%
def extract_documents_from_pdf(url):
    # response = requests.get(url)
    # print(response.headers.get('content-type'))
    # with open('temp_pdf.pdf', 'wb') as f:
    #     f.write(response.content)

    with open('/home/alejandro/Documents/NUS study material/Term 2/SA52 Digital Product Management/Supplementary reading/scrumprimer20.pdf', 'rb') as f:
        pdf_reader = PdfReader(f)
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            yield page.extract_text()
            
url = 'https://procrastinatingbucket.sgp1.cdn.digitaloceanspaces.com/Procrastinate/Procrastinate%20jane12/upload/0e726bf2'
docs = list(extract_documents_from_pdf(url))
# Out:
# 2024-04-22 17:43:19,335 : WARNING : Ignoring wrong pointing object 44 0 (offset 0)

# %%
cleaned_docs = []

for doc in docs:
    punc_removed = re.sub('[,\.!?]', '', doc)
    case_lowered = punc_removed.lower()
    fillers_removed_doc = re.sub(
        r'\b(?:okay|right|going|thing|kind|really|thing|one|lot|see|look|might|actually|now|different|pretty|think|kind|maybe|want|need|understand|well|like|little|could|say|also|all|can|will|welcome|our|first|lecture|to|up|try|broadly|where|is|about|the|just|do|get)\b',
        '',
        case_lowered
    )
    
    
    cleaned_docs.append(fillers_removed_doc)
    

docs = cleaned_docs
print(docs)
# Out:
# ['1\na lightweight guide   theory and practice of scrumversion 20pete deemergoodagilewwwgoodagilecomgabrielle benefieldevolvewwwevolvebeyondcomcraig larmanwwwcraiglarmancombas voddeodd-ewwwodd-ecom', 'a note  readers: there are many concise descriptions of scrum available online and this primer aims  provide  next level of detail on  practices it  not intended as  final step in a scrum education; teams that are considering adopting scrum are advised  equip themselves with ken schwaber’s agile project management with scrum or mike cohn’s succeeding with agile and take advantage of  many excellent scrum training and coaching options that are available; full details are at scrumallianceorg  thanks go  ken schwaber dr jeff sutherland and mike cohn for their generous inputthe latest version of   primer  be found at: http://wwwinfoqcom/minibooks/scrum_primertranslations  be found at: http://wwwscrumprimerorg/© 2012 pete deemer gabrielle benefield craig larman bas vodde\n2', 'beyond traditional developmenttraditional development with single-function groups delayed or weak feedback loops front-loaded\xa0predictive planning and a sequential flow from analysis  test  not very successful in today’s volatile world this approach delays feedback learning and potential return on investment due  an absence of  real working software until late in  game causing a lack of  transparency lack of  ability  improve reduction in flexibility and an increase in business and technical\xa0risks\xa0an alternative – cross-functional teams with iterative development\xa0– has  existed for decades but was not as widely used as  traditional modelscrum packages proven product-development concepts in a simple framework including: real teams cross-functional teams self-managing teams\xa0short iterative full-cycle feedback loops and lowering  cost of  change these concepts increase agility and feedback enable earlier roi and reduce riskoverviewscrum  a development framework in which cross-functional teams develop products or projects in an iterative incremental manner it structures development in cycles of work called sprints these iterations are no more than four weeks each ( most common  two weeks) and take place  after  other without pause  sprints are timeboxed – they end on a specific date whether  work has been completed or not and are never extended usually scrum teams choose  sprint length and use it for  their sprints until they improve and  use a shorter cycle at  beginning of each sprint a cross-functional team (of  seven people) selects items (customer requirements) from a prioritized list  team agrees on a collective target of what they believe they  deliver by  end of  sprint something that  tangible and  be truly “done”  during  sprint no new items may be added; scrum embraces change for  next sprint but  current short sprint  meant  focus on a small clear relatively stable goal every day  team gathers briefly  inspect its progress and adjust  next steps needed  complete  work remaining at  end of  sprint  team reviews  sprint with stakeholders and demonstrates what it has built people obtain feedback that  be incorporated in  next sprint scrum emphasizes working product at  end of  sprint that   “done”; in  case of software this means a system that  integrated fully tested end-user documented and potentially shippable key roles artifacts and events are summarized in figure 1\nfigure 1 scrum overview\nsprintdailyscrum\nno changes  goalone  four weeksproduct owner\nproductbacklogsprintreviewteam\nproductbacklogsprintbacklogscrum\nitemswork\npotentially shippableproduct incrementsprint planningpart 1 and 2product backlogrefinement\nretrospectivescrum master\n3', 'a major theme in scrum  “inspect and adapt” since development inevitably involves learning innovation and surprises scrum emphasizes taking a short step of development inspecting both  resulting product and  efficacy of current practices and then adapting  product goals and process practices  ...
# <>:4: DeprecationWarning: invalid escape sequence '\.'
# <>:4: DeprecationWarning: invalid escape sequence '\.'
# /tmp/ipykernel_140468/55492016.py:4: DeprecationWarning: invalid escape sequence '\.'
#   punc_removed = re.sub('[,\.!?]', '', doc)

# %%
def tokeniz(sentences):

    for sentence in sentences:

        yield(gensim.utils.simple_preprocess(str(sentence), deacc=True))

processed_data = list(tokeniz(docs))
print(processed_data)
# Out:
# [['lightweight', 'guide', 'theory', 'and', 'practice', 'of', 'scrumversion', 'pete', 'voddeodd', 'ewwwodd', 'ecom'], ['note', 'readers', 'there', 'are', 'many', 'concise', 'descriptions', 'of', 'scrum', 'available', 'online', 'and', 'this', 'primer', 'aims', 'provide', 'next', 'level', 'of', 'detail', 'on', 'practices', 'it', 'not', 'intended', 'as', 'final', 'step', 'in', 'scrum', 'education', 'teams', 'that', 'are', 'considering', 'adopting', 'scrum', 'are', 'advised', 'equip', 'themselves', 'with', 'ken', 'schwaber', 'agile', 'project', 'management', 'with', 'scrum', 'or', 'mike', 'cohn', 'succeeding', 'with', 'agile', 'and', 'take', 'advantage', 'of', 'many', 'excellent', 'scrum', 'training', 'and', 'coaching', 'options', 'that', 'are', 'available', 'full', 'details', 'are', 'at', 'thanks', 'go', 'ken', 'schwaber', 'dr', 'jeff', 'sutherland', 'and', 'mike', 'cohn', 'for', 'their', 'generous', 'inputthe', 'latest', 'version', 'of', 'primer', 'be', 'found', 'at', 'http', 'wwwinfoqcom', 'minibooks', 'be', 'found', 'at', 'http', 'pete', 'deemer', 'gabrielle', 'benefield', 'craig', 'larman', 'bas', 'vodde'], ['beyond', 'traditional', 'development', 'with', 'single', 'function', 'groups', 'delayed', 'or', 'weak', 'feedback', 'loops', 'front', 'loaded', 'predictive', 'planning', 'and', 'sequential', 'flow', 'from', 'analysis', 'test', 'not', 'very', 'successful', 'in', 'today', 'volatile', 'world', 'this', 'approach', 'delays', 'feedback', 'learning', 'and', 'potential', 'return', 'on', 'investment', 'due', 'an', 'absence', 'of', 'real', 'working', 'software', 'until', 'late', 'in', 'game', 'causing', 'lack', 'of', 'transparency', 'lack', 'of', 'ability', 'improve', 'reduction', 'in', 'flexibility', 'and', 'an', 'increase', 'in', 'business', 'and', 'technical', 'risks', 'an', 'alternative', 'cross', 'functional', 'teams', 'with', 'iterative', 'development', 'has', 'existed', 'for', 'decades', 'but', 'was', 'not', 'as', 'widely', 'used', 'as', 'traditional', 'modelscrum', 'packages', 'proven', 'product', 'development', 'concepts', 'in', 'simple', 'framework', 'including', 'real', 'teams', 'cross', 'functional', 'teams', 'self', 'managing', 'teams', 'short', 'iterative', 'full', 'cycle', 'feedback', 'loops', 'and', 'lowering', 'cost', 'of', 'change', 'these', 'concepts', 'increase', 'agility', 'and', 'feedback', 'enable', 'earlier', 'roi', 'and', 'reduce', 'development', 'framework', 'in', 'which', 'cross', 'functional', 'teams', 'develop', 'products', 'or', 'projects', 'in', 'an', 'iterative', 'incremental', 'manner', 'it', 'structures', 'development', 'in', 'cycles', 'of', 'work', 'called', 'sprints', 'these', 'iterations', 'are', 'no', 'more', 'than', 'four', 'weeks', 'each', 'most', 'common', 'two', 'weeks', 'and', 'take', 'place', 'after', 'other', 'without', 'pause', 'sprints', 'are', 'timeboxed', 'they', 'end', 'on', 'specific', 'date', 'whether', 'work', 'has', 'been', 'completed', 'or', 'not', 'and', 'are', 'never', 'extended', 'usually', 'scrum', 'teams', 'choose', 'sprint', 'length', 'and', 'use', 'it', 'for', 'their', 'sprints', 'until', 'they', 'improve', 'and', 'use', 'shorter', 'cycle', 'at', 'beginning', 'of', 'each', 'sprint', 'cross', 'functional', 'team', 'of', 'seven', 'people', 'selects', 'items', 'customer', 'requirements', 'from', 'prioritized', 'list', 'team', 'agrees', 'on', 'collective', 'target', 'of', 'what', 'they', 'believe', 'they', 'deliver', 'by', 'end', 'of', 'sprint', 'something', 'that', 'tangible', 'and', 'be', 'truly', 'done', 'during', 'sprint', 'no', 'new', 'items', 'may', 'be', 'added', 'scrum', 'embraces', 'change', 'for', 'next', 'sprint', 'but', 'current', 'short', 'sprint', 'meant', 'focus', 'on', 'small', 'clear', 'relatively', 'stable', 'goal', 'every', 'day', 'team', 'gathers', 'briefly', 'inspect', 'its', 'progress', 'and', 'adjust', 'next', 'steps', 'needed', 'complete', 'work', 'remaining', 'at', 'end', 'of', 'sprint', 'team', 'reviews', 'sprint', 'with', 'stakeholders', 'and', 'de ...

# %%
def remove_stopwords(texts):

    return [[word for word in simple_preprocess(str(doc)) if word not in stop_words] for doc in texts]

def lemmatize(texts, allowed_postags=['NOUN', 'ADJ', 'VERB']):

    texts_op = []

    for sent in texts:

        doc = nlp(" ".join(sent))

        texts_op.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])

    return texts_op

# %%
stop_words = stopwords.words('english')

stop_words.extend(['from', 'subject', 're', 'edu', 'use','for'])
data_wo_stopwords = remove_stopwords(processed_data)
print(data_wo_stopwords)
# Out:
# [['lightweight', 'guide', 'theory', 'practice', 'scrumversion', 'pete', 'voddeodd', 'ewwwodd', 'ecom'], ['note', 'readers', 'many', 'concise', 'descriptions', 'scrum', 'available', 'online', 'primer', 'aims', 'provide', 'next', 'level', 'detail', 'practices', 'intended', 'final', 'step', 'scrum', 'education', 'teams', 'considering', 'adopting', 'scrum', 'advised', 'equip', 'ken', 'schwaber', 'agile', 'project', 'management', 'scrum', 'mike', 'cohn', 'succeeding', 'agile', 'take', 'advantage', 'many', 'excellent', 'scrum', 'training', 'coaching', 'options', 'available', 'full', 'details', 'thanks', 'go', 'ken', 'schwaber', 'dr', 'jeff', 'sutherland', 'mike', 'cohn', 'generous', 'inputthe', 'latest', 'version', 'primer', 'found', 'http', 'wwwinfoqcom', 'minibooks', 'found', 'http', 'pete', 'deemer', 'gabrielle', 'benefield', 'craig', 'larman', 'bas', 'vodde'], ['beyond', 'traditional', 'development', 'single', 'function', 'groups', 'delayed', 'weak', 'feedback', 'loops', 'front', 'loaded', 'predictive', 'planning', 'sequential', 'flow', 'analysis', 'test', 'successful', 'today', 'volatile', 'world', 'approach', 'delays', 'feedback', 'learning', 'potential', 'return', 'investment', 'due', 'absence', 'real', 'working', 'software', 'late', 'game', 'causing', 'lack', 'transparency', 'lack', 'ability', 'improve', 'reduction', 'flexibility', 'increase', 'business', 'technical', 'risks', 'alternative', 'cross', 'functional', 'teams', 'iterative', 'development', 'existed', 'decades', 'widely', 'used', 'traditional', 'modelscrum', 'packages', 'proven', 'product', 'development', 'concepts', 'simple', 'framework', 'including', 'real', 'teams', 'cross', 'functional', 'teams', 'self', 'managing', 'teams', 'short', 'iterative', 'full', 'cycle', 'feedback', 'loops', 'lowering', 'cost', 'change', 'concepts', 'increase', 'agility', 'feedback', 'enable', 'earlier', 'roi', 'reduce', 'development', 'framework', 'cross', 'functional', 'teams', 'develop', 'products', 'projects', 'iterative', 'incremental', 'manner', 'structures', 'development', 'cycles', 'work', 'called', 'sprints', 'iterations', 'four', 'weeks', 'common', 'two', 'weeks', 'take', 'place', 'without', 'pause', 'sprints', 'timeboxed', 'end', 'specific', 'date', 'whether', 'work', 'completed', 'never', 'extended', 'usually', 'scrum', 'teams', 'choose', 'sprint', 'length', 'sprints', 'improve', 'shorter', 'cycle', 'beginning', 'sprint', 'cross', 'functional', 'team', 'seven', 'people', 'selects', 'items', 'customer', 'requirements', 'prioritized', 'list', 'team', 'agrees', 'collective', 'target', 'believe', 'deliver', 'end', 'sprint', 'something', 'tangible', 'truly', 'done', 'sprint', 'new', 'items', 'may', 'added', 'scrum', 'embraces', 'change', 'next', 'sprint', 'current', 'short', 'sprint', 'meant', 'focus', 'small', 'clear', 'relatively', 'stable', 'goal', 'every', 'day', 'team', 'gathers', 'briefly', 'inspect', 'progress', 'adjust', 'next', 'steps', 'needed', 'complete', 'work', 'remaining', 'end', 'sprint', 'team', 'reviews', 'sprint', 'stakeholders', 'demonstrates', 'built', 'people', 'obtain', 'feedback', 'incorporated', 'next', 'sprint', 'scrum', 'emphasizes', 'working', 'product', 'end', 'sprint', 'done', 'case', 'software', 'means', 'system', 'integrated', 'fully', 'tested', 'end', 'user', 'documented', 'potentially', 'shippable', 'key', 'roles', 'artifacts', 'events', 'summarized', 'figure', 'figure', 'scrum', 'overview', 'changes', 'goalone', 'four', 'weeksproduct', 'owner', 'itemswork', 'potentially', 'incrementsprint', 'planningpart', 'product', 'master'], ['major', 'theme', 'scrum', 'inspect', 'adapt', 'since', 'development', 'inevitably', 'involves', 'learning', 'innovation', 'surprises', 'scrum', 'emphasizes', 'taking', 'short', 'step', 'development', 'inspecting', 'resulting', 'product', 'efficacy', 'current', 'practices', 'adapting', 'product', 'goals', 'process', 'practices', 'repeat', 'foreverscrum', 'rolesin', 'scrum', 'three', 'roles', 'product', 'owner', 'team',  ...

# %%
bigram = gensim.models.Phrases(processed_data, min_count=5, threshold=100)
bigram_mod = gensim.models.phrases.Phraser(bigram)

def create_bigrams(texts):

    return [bigram_mod[doc] for doc in texts]
# Out:
# 2024-04-22 17:43:20,091 : INFO : collecting all words and their counts
# 2024-04-22 17:43:20,092 : INFO : PROGRESS: at sentence #0, processed 0 words and 0 word types
# 2024-04-22 17:43:20,099 : INFO : collected 7643 token types (unigram + bigrams) from a corpus of 8007 words and 20 sentences
# 2024-04-22 17:43:20,099 : INFO : merged Phrases<7643 vocab, min_count=5, threshold=100, max_vocab_size=40000000>
# 2024-04-22 17:43:20,099 : INFO : Phrases lifecycle event {'msg': 'built Phrases<7643 vocab, min_count=5, threshold=100, max_vocab_size=40000000> in 0.01s', 'datetime': '2024-04-22T17:43:20.099810', 'gensim': '4.3.2', 'python': '3.10.14 (main, Mar 21 2024, 16:24:04) [GCC 11.2.0]', 'platform': 'Linux-6.5.0-10031-tuxedo-x86_64-with-glibc2.35', 'event': 'created'}
# 2024-04-22 17:43:20,100 : INFO : exporting phrases from Phrases<7643 vocab, min_count=5, threshold=100, max_vocab_size=40000000>
# 2024-04-22 17:43:20,105 : INFO : FrozenPhrases lifecycle event {'msg': 'exported FrozenPhrases<9 phrases, min_count=5, threshold=100> from Phrases<7643 vocab, min_count=5, threshold=100, max_vocab_size=40000000> in 0.00s', 'datetime': '2024-04-22T17:43:20.105401', 'gensim': '4.3.2', 'python': '3.10.14 (main, Mar 21 2024, 16:24:04) [GCC 11.2.0]', 'platform': 'Linux-6.5.0-10031-tuxedo-x86_64-with-glibc2.35', 'event': 'created'}

# %%
data_bigrams = create_bigrams(data_wo_stopwords)

# %%
import spacy
nlp=spacy.load('en_core_web_sm',disable=['parser', 'ner'])
data_lemmatized = lemmatize(data_bigrams, allowed_postags=[ 'NOUN', 'ADJ', 'VERB'])

# %%
gensim_dictionary = corpora.Dictionary(data_lemmatized)
# Out:
# 2024-04-22 17:43:21,575 : INFO : adding document #0 to Dictionary<0 unique tokens: []>
# 2024-04-22 17:43:21,578 : INFO : built Dictionary<1124 unique tokens: ['ewwwodd', 'guide', 'lightweight', 'pete', 'practice']...> from 20 documents (total 4610 corpus positions)
# 2024-04-22 17:43:21,579 : INFO : Dictionary lifecycle event {'msg': "built Dictionary<1124 unique tokens: ['ewwwodd', 'guide', 'lightweight', 'pete', 'practice']...> from 20 documents (total 4610 corpus positions)", 'datetime': '2024-04-22T17:43:21.579170', 'gensim': '4.3.2', 'python': '3.10.14 (main, Mar 21 2024, 16:24:04) [GCC 11.2.0]', 'platform': 'Linux-6.5.0-10031-tuxedo-x86_64-with-glibc2.35', 'event': 'created'}

# %%
texts = data_lemmatized

# %%
gensim_corpus = [gensim_dictionary.doc2bow(text) for text in texts]

# %%
[[(gensim_dictionary[id], freq) for id, freq in cp] for cp in gensim_corpus[:4]]
# Out:
# [[('ewwwodd', 1),
#   ('guide', 1),
#   ('lightweight', 1),
#   ('pete', 1),
#   ('practice', 1),
#   ('scrumversion', 1),
#   ('theory', 1),
#   ('voddeodd', 1)],
#  [('pete', 1),
#   ('practice', 1),
#   ('adopt', 1),
#   ('advantage', 1),
#   ('advise', 1),
#   ('agile', 2),
#   ('aim', 1),
#   ('available', 2),
#   ('coaching', 1),
#   ('concise', 1),
#   ('consider', 1),
#   ('deemer', 1),
#   ('description', 1),
#   ('detail', 2),
#   ('education', 1),
#   ('excellent', 1),
#   ('final', 1),
#   ('find', 2),
#   ('full', 1),
#   ('go', 1),
#   ('http', 1),
#   ('intend', 1),
#   ('late', 1),
#   ('level', 1),
#   ('management', 1),
#   ('many', 2),
#   ('next', 1),
#   ('note', 1),
#   ('online', 1),
#   ('option', 1),
#   ('primer', 2),
#   ('project', 1),
#   ('provide', 1),
#   ('reader', 1),
#   ('scrum', 5),
#   ('step', 1),
#   ('succeed', 1),
#   ('take', 1),
#   ('team', 1),
#   ('thank', 1),
#   ('training', 1),
#   ('version', 1)],
#  [('full', 1),
#   ('late', 1),
#   ('next', 3),
#   ('project', 1),
#   ('scrum', 4),
#   ('step', 1),
#   ('take', 1),
#   ('team', 10),
#   ('ability', 1),
#   ('absence', 1),
#   ('added', 1),
#   ('adjust', 1),
#   ('agility', 1),
#   ('agree', 1),
#   ('alternative', 1),
#   ('analysis', 1),
#   ('approach', 1),
#   ('artifact', 1),
#   ('begin', 1),
#   ('believe', 1),
#   ('build', 1),
#   ('business', 1),
#   ('call', 1),
#   ('case', 1),
#   ('cause', 1),
#   ('change', 3),
#   ('choose', 1),
#   ('clear', 1),
#   ('collective', 1),
#   ('common', 1),
#   ('complete', 2),
#   ('concept', 2),
#   ('cost', 1),
#   ('cross_functional', 4),
#   ('current', 1),
#   ('customer', 1),
#   ('cycle', 3),
#   ('date', 1),
#   ('day', 1),
#   ('decade', 1),
#   ('delay', 2),
#   ('demonstrate', 1),
#   ('develop', 1),
#   ('development', 5),
#   ('do', 2),
#   ('document', 1),
#   ('due', 1),
#   ('early', 1),
#   ('embrace', 1),
#   ('emphasize', 1),
#   ('enable', 1),
#   ('end', 5),
#   ('event', 1),
#   ('exist', 1),
#   ('extend', 1),
#   ('feedback', 5),
#   ('figure', 2),
#   ('flexibility', 1),
#   ('flow', 1),
#   ('focus', 1),
#   ('framework', 2),
#   ('front', 1),
#   ('function', 1),
#   ('game', 1),
#   ('gather', 1),
#   ('goal', 1),
#   ('goalone', 1),
#   ('group', 1),
#   ('improve', 2),
#   ('include', 1),
#   ('incorporate', 1),
#   ('increase', 2),
#   ('incremental', 1),
#   ('incrementsprint', 1),
#   ('inspect', 1),
#   ('integrate', 1),
#   ('investment', 1),
#   ('item', 2),
#   ('itemswork', 1),
#   ('iteration', 1),
#   ('iterative', 3),
#   ('key', 1),
#   ('lack', 2),
#   ('learn', 1),
#   ('length', 1),
#   ('list', 1),
#   ('load', 1),
#   ('loop', 2),
#   ('lower', 1),
#   ('manage', 1),
#   ('manner', 1),
#   ('master', 1),
#   ('mean', 2),
#   ('modelscrum', 1),
#   ('need', 1),
#   ('new', 1),
#   ('obtain', 1),
#   ('overview', 1),
#   ('owner', 1),
#   ('package', 1),
#   ('pause', 1),
#   ('people', 2),
#   ('place', 1),
#   ('planning', 1),
#   ('planningpart', 1),
#   ('potential', 1),
#   ('potentially_shippable', 1),
#   ('predictive', 1),
#   ('prioritize', 1),
#   ('product', 4),
#   ('progress', 1),
#   ('prove', 1),
#   ('real', 2),
#   ('reduce', 1),
#   ('reduction', 1),
#   ('remain', 1),
#   ('requirement', 1),
#   ('return', 1),
#   ('review', 1),
#   ('risk', 1),
#   ('roi', 1),
#   ('role', 1),
#   ('select', 1),
#   ('self', 1),
#   ('sequential', 1),
#   ('short', 3),
#   ('simple', 1),
#   ('single', 1),
#   ('small', 1),
#   ('software', 2),
#   ('specific', 1),
#   ('sprint', 13),
#   ('stable', 1),
#   ('stakeholder', 1),
#   ('structure', 1),
#   ('successful', 1),
#   ('summarize', 1),
#   ('system', 1),
#   ('tangible', 1),
#   ('target', 1),
#   ('technical', 1),
#   ('test', 2),
#   ('timeboxe', 1),
#   ('today', 1),
#   ('traditional', 2),
#   ('transparency', 1),
#   ('use', 1),
#   ('user', 1),
#   ('volatile', 1),
#   ('weak', 1),
#   ('week', 2),
#   ('weeksproduct', 1),
#   ('work', 5),
#   ('world', 1)],
#  [('practice', 3),
#   ('adopt', 1),
#   ('final', 1),
#   ('go', 1),
#   ('many', 3),
#   ('next', 1),
#   ('note', 1),
#   ('project', 2),
#   ('provide', 1),
#   ('scrum', 8),
#   ('step', 1),
#   ('take', 2),
#   ('team', 22),
#   ('analysis', 3),
#   ('build', 2),
#   ('business', 1),
#   ('call', 1),
#   ('case', 3),
#   ('change', 1),
#   ('choose', 1),
#   ('common', 1),
#   ('complete', 2),
#   ('current', 1),
#   ('customer', 4),
#   ('demonstrate', 1),
#   ('develop', 1),
#   ('development', 5),
#   ('emphasize', 1),
#   ('focus', 1),
#   ('goal', 3),
#   ('group', 2),
#   ('improve', 1),
#   ('include', 2),
#   ('inspect', 2),
#   ('investment', 1),
#   ('item', 3),
#   ('key', 1),
#   ('learn', 3),
#   ('list', 3),
#   ('manage', 1),
#   ('mean', 1),
#   ('need', 1),
#   ('owner', 11),
#   ('people', 4),
#   ('potentially_shippable', 1),
#   ('prioritize', 2),
#   ('product', 30),
#   ('return', 1),
#   ('review', 1),
#   ('risk', 1),
#   ('roi', 3),
#   ('role', 2),
#   ('self', 2),
#   ('short', 1),
#   ('software', 1),
#   ('sprint', 7),
#   ('stable', 1),
#   ('stakeholder', 1),
#   ('technical', 1),
#   ('traditional', 1),
#   ('work', 7),
#   ('accomplish', 1),
#   ('accountability', 1),
#   ('achieve', 1),
#   ('adapt', 2),
#   ('alignment', 1),
#   ('analyst', 1),
#   ('application', 3),
#   ('appropriate', 1),
#   ('architecture', 1),
#   ('area', 1),
#   ('associate', 1),
#   ('assume', 1),
#   ('attack', 1),
#   ('attention', 1),
#   ('authority', 1),
#   ('automate', 1),
#   ('autonomy', 1),
#   ('avoid', 3),
#   ('centric', 1),
#   ('close', 1),
#   ('commercial', 2),
#   ('context', 1),
#   ('continue', 1),
#   ('coordination', 1),
#   ('costly', 1),
#   ('database', 1),
#   ('decide', 2),
#   ('decision', 1),
#   ('dedicated', 1),
#   ('degree', 1),
#   ('delegate', 1),
#   ('deliver', 1),
#   ('design', 3),
#   ('designer', 1),
#   ('desire', 1),
#   ('divide', 1),
#   ('documentation', 1),
#   ('drain', 1),
#   ('effective', 1),
#   ('efficacy', 1),
#   ('effort', 1),
#   ('example', 2),
#   ('expertise', 1),
#   ('factor', 1),
#   ('familiar', 1),
#   ('feature', 4),
#   ('fix', 1),
#   ('foreverscrum', 1),
#   ('fuzzy', 1),
#   ('generate', 1),
#   ('good', 1),
#   ('great', 1),
#   ('help', 2),
#   ('high', 3),
#   ('idea', 1),
#   ('identify', 1),
#   ('indicate', 1),
#   ('individual', 1),
#   ('influence', 1),
#   ('innovation', 1),
#   ('interact', 1),
#   ('interaction', 2),
#   ('interface', 1),
#   ('internal', 2),
#   ('involve', 1),
#   ('know', 2),
#   ('lead', 1),
#   ('loss', 1),
#   ('major', 1),
#   ('make', 1),
#   ('manager', 4),
#   ('marketing', 1),
#   ('maximize', 2),
#   ('member', 5),
#   ('million', 1),
#   ('multi', 1),
#   ('multiple', 2),
#   ('necessary', 1),
#   ('notice', 1),
#   ('objective', 1),
#   ('offer', 1),
#   ('organization', 1),
#   ('organize', 2),
#   ('other', 1),
#   ('percent', 1),
#   ('person', 6),
#   ('plan', 1),
#   ('position', 1),
#   ('primary', 3),
#   ('prioritization', 1),
#   ('prioritized', 1),
#   ('process', 1),
#   ('productive', 1),
#   ('productivity', 1),
#   ('profit', 1),
#   ('programmer', 1),
#   ('programming', 1),
#   ('programmingthe', 1),
#   ('refining', 1),
#   ('repeat', 1),
#   ('responsibility', 1),
#   ('responsible', 4),
#   ('result', 2),
#   ('revenue', 1),
#   ('rolesin', 1),
#   ('satisfy', 1),
#   ('scrummaster', 1),
#   ('secondary', 2),
#   ('sense', 2),
#   ('serve', 1),
#   ('set', 2),
#   ('similar', 1),
#   ('skill', 5),
#   ('special', 1),
#   ('specialty', 1),
#   ('strategic', 1),
#   ('strength', 1),
#   ('surprise', 1),
#   ('switch', 1),
#   ('task', 2),
#   ('term', 1),
#   ('tertiary', 1),
#   ('testing', 3),
#   ('theme', 1),
#   ('themselvessince', 1),
#   ('title', 1),
#   ('top', 1),
#   ('translate', 1),
#   ('value', 3),
#   ('variety', 1),
#   ('way', 1),
#   ('website', 1),
#   ('writing', 1)]]

# %%
lda_model = gensim.models.ldamodel.LdaModel(

   corpus=gensim_corpus, id2word=gensim_dictionary, num_topics=15, random_state=100, 

   update_every=1, chunksize=100, passes=10, alpha='auto', per_word_topics=True

)
# Out:
# 2024-04-22 17:43:21,650 : INFO : using autotuned alpha, starting with [0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667, 0.06666667]
# 2024-04-22 17:43:21,651 : INFO : using symmetric eta at 0.06666666666666667
# 2024-04-22 17:43:21,653 : INFO : using serial LDA version on this node
# 2024-04-22 17:43:21,654 : INFO : running online (multi-pass) LDA training, 15 topics, 10 passes over the supplied corpus of 20 documents, updating model once every 20 documents, evaluating perplexity every 20 documents, iterating 50x with a convergence threshold of 0.001000
# 2024-04-22 17:43:21,664 : INFO : -12.857 per-word bound, 7421.4 perplexity estimate based on a held-out corpus of 20 documents with 4610 words
# 2024-04-22 17:43:21
"work" + 0.018*"backlog" + 0.013*"scrum" + 0.009*"complete" + 0.009*"estimate"
# 2024-04-22 17:43:21,790 : INFO : topic diff=0.188904, rho=0.333333
# 2024-04-22 17:43:21,797 : INFO : -6.455 per-word bound, 87.7 perplexity estimate based on a held-out corpus of 20 documents with 4610 words
# 2024-04-22 17:43:21,798 : INFO : PROGRESS: pass 8, at document #20/20
# 2024-04-22 17:43:21,801 : INFO : optimized alpha [0.037994284, 0.028852634, 0.027825335, 0.20380725, 0.027019344, 0.03435505, 0.03859201, 0.03193466, 0.03368476, 0.029010866, 0.03938025, 0.024990996, 0.029461922, 0.037587464, 0.03971238]
# 2024-04-22 17:43:21,802 : INFO : topic #11 (0.025): 0.001*"team" + 0.001*"scrum" + 0.001*"make" + 0.001*"sprint" + 0.001*"owner" + 0.001*"manager" + 0.001*"product" + 0.001*"scrummaster" + 0.001*"change" + 0.001*"help"
# 2024-04-22 17:43:21,803 : INFO : topic #4 (0.027): 0.001*"team" + 0.001*"product" + 0.001*"sprint" + 0.001*"item" + 0.001*"owner" + 0.001*"work" + 0.001*"backlog" + 0.001*"end" + 0.001*"estimate" + 0.001*"scrum"
# 2024-04-22 17:43:21,803 : INFO : topic #10 (0.039): 0.043*"scrum" + 0.034*"agile" + 0.029*"primer" + 0.024*"scale" + 0.020*"team" + 0.019*"development" + 0.019*"lean" + 0.015*"large" + 0.015*"material" + 0.015*"description"
# 2024-04-22 17:43:21,803 : INFO : topic #14 (0.040): 0.047*"team" + 0.033*"scrum" + 0.028*"task" + 0.027*"sprint" + 0.014*"make" + 0.014*"learn" + 0.011*"work" + 0.010*"practice" + 0.010*"experience" + 0.010*"rare"
# 2024-04-22 17:43:21,803 : INFO : topic #3 (0.204): 0.053*"product" + 0.047*"team" + 0.041*"sprint" + 0.025*"item" + 0.022*"owner" + 0.020*"work" + 0.018*"backlog" + 0.013*"scrum" + 0.009*"complete" + 0.009*"meeting"
# 2024-04-22 17:43:21,804 : INFO : topic diff=0.134520, rho=0.316228
# 2024-04-22 17:43:21,811 : INFO : -6.445 per-word bound, 87.1 perplexity estimate based on a held-out corpus of 20 documents with 4610 words
# 2024-04-22 17:43:21,812 : INFO : PROGRESS: pass 9, at document #20/20
# 2024-04-22 17:43:21,815 : INFO : optimized alpha [0.036400463, 0.027142256, 0.026234442, 0.20023899, 0.02551918, 0.03255915, 0.03692432, 0.03040309, 0.031955495, 0.027281703, 0.037600297, 0.023707405, 0.027678642, 0.036032416, 0.03793968]
# 2024-04-22 17:43:21,816 : INFO : topic #11 (0.024): 0.001*"team" + 0.001*"scrum" + 0.001*"make" + 0.001*"sprint" + 0.001*"owner" + 0.001*"manager" + 0.001*"product" + 0.001*"scrummaster" + 0.001*"change" + 0.001*"help"
# 2024-04-22 17:43:21,817 : INFO : topic #4 (0.026): 0.001*"team" + 0.001*"product" + 0.001*"sprint" + 0.001*"item" + 0.001*"owner" + 0.001*"work" + 0.001*"backlog" + 0.001*"end" + 0.001*"estimate" + 0.001*"scrum"
# 2024-04-22 17:43:21,817 : INFO : topic #10 (0.038): 0.043*"scrum" + 0.034*"agile" + 0.029*"primer" + 0.024*"scale" + 0.020*"team" + 0.019*"development" + 0.019*"lean" + 0.015*"large" + 0.015*"material" + 0.015*"description"
# 2024-04-22 17:43:21,818 : INFO : topic #14 (0.038): 0.047*"team" + 0.033*"scrum" + 0.028*"task" + 0.027*"sprint" + 0.014*"make" + 0.014*"learn" + 0.011*"work" + 0.010*"practice" + 0.010*"experience" + 0.010*"rare"
# 2024-04-22 17:43:21,819 : INFO : topic #3 (0.200): 0.053*"product" + 0.047*"team" + 0.041*"sprint" + 0.025*"item" + 0.022*"owner" + 0.020*"work" + 0.018*"backlog" + 0.013*"scrum" + 0.009*"complete" + 0.009*"meeting"
# 2024-04-22 17:43:21,819 : INFO : topic diff=0.096710, rho=0.301511
# 2024-04-22 17:43:21,820 : INFO : LdaModel lifecycle event {'msg': 'trained LdaModel<num_terms=1124, num_topics=15, decay=0.5, chunksize=100> in 0.17s', 'datetime': '2024-04-22T17:43:21.820228', 'gensim': '4.3.2', 'python': '3.10.14 (main, Mar 21 2024, 16:24:04) [GCC 11.2.0]', 'platform': 'Linux-6.5.0-10031-tuxedo-x86_64-with-glibc2.35', 'event': 'created'}

# %%
from gensim.models import CoherenceModel
coherence_model_lda = CoherenceModel(

   model=lda_model, texts=data_lemmatized, dictionary=gensim_dictionary, coherence='c_v')

coherence_lda = coherence_model_lda.get_coherence()

print('\nCoherence Score: ', coherence_lda)
# Out:
# 2024-04-22 17:49:30,343 : INFO : using ParallelWordOccurrenceAccumulator<processes=19, batch_size=64> to estimate probabilities from sliding windows
# 2024-04-22 17:49:30,540 : INFO : 1 batches submitted to accumulate stats from 64 documents (2430 virtual)
# 2024-04-22 17:49:30,543 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,543 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,543 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,544 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,543 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,544 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,544 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,544 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,544 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,545 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,544 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,545 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,545 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,545 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,546 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,546 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,547 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,545 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,546 : INFO : accumulator serialized
# 2024-04-22 17:49:30,548 : INFO : accumulator serialized
# 2024-04-22 17:49:30,549 : INFO : accumulator serialized
# 2024-04-22 17:49:30,549 : INFO : accumulator serialized
# 2024-04-22 17:49:30,548 : INFO : accumulator serialized
# 2024-04-22 17:49:30,549 : INFO : accumulator serialized
# 2024-04-22 17:49:30,549 : INFO : accumulator serialized
# 2024-04-22 17:49:30,549 : INFO : accumulator serialized
# 2024-04-22 17:49:30,549 : INFO : accumulator serialized
# 2024-04-22 17:49:30,549 : INFO : accumulator serialized
# 2024-04-22 17:49:30,549 : INFO : accumulator serialized
# 2024-04-22 17:49:30,550 : INFO : accumulator serialized
# 2024-04-22 17:49:30,550 : INFO : accumulator serialized
# 2024-04-22 17:49:30,550 : INFO : accumulator serialized
# 2024-04-22 17:49:30,549 : INFO : accumulator serialized
# 2024-04-22 17:49:30,552 : INFO : accumulator serialized
# 2024-04-22 17:49:30,555 : INFO : accumulator serialized
# 2024-04-22 17:49:30,552 : INFO : accumulator serialized
# 2024-04-22 17:49:30,650 : INFO : serializing accumulator to return to master...
# 2024-04-22 17:49:30,653 : INFO : accumulator serialized
# 2024-04-22 17:49:30,669 : INFO : 19 accumulators retrieved from output queue
# 2024-04-22 17:49:30,679 : INFO : accumulated word occurrence stats for 2619 virtual documents
# Coherence Score:  0.3881221702280015

# %%
top_topics = lda_model.top_topics(gensim_corpus)

# Average topic coherence is the sum of topic coherences of all topics, divided by the number of topics.
avg_topic_coherence = sum([t[1] for t in top_topics]) / 15
print('Average topic coherence: %.4f.' % avg_topic_coherence)

from pprint import pprint
pprint(top_topics)
# Out:
# Average topic coherence: -1.2611.
# [([(0.0027059228, 'product'),
#    (0.0024801062, 'sprint'),
#    (0.0024746726, 'team'),
#    (0.0016836356, 'item'),
#    (0.0015677897, 'backlog'),
#    (0.0014314686, 'scrum'),
#    (0.0013741505, 'owner'),
#    (0.0012754347, 'work'),
#    (0.0012494373, 'estimate'),
#    (0.0012267166, 'make'),
#    (0.0011714958, 'new'),
#    (0.0011593519, 'change'),
#    (0.0011409358, 'end'),
#    (0.001132118, 'time'),
#    (0.0011009972, 'development'),
#    (0.0010999211, 'complete'),
#    (0.0010936931, 'task'),
#    (0.0010747345, 'figure'),
#    (0.0010572264, 'help'),
#    (0.0010548388, 'goal')],
#   -0.5354332932761495),
#  ([(0.053440496, 'product'),
#    (0.046770755, 'team'),
#    (0.040912293, 'sprint'),
#    (0.025391417, 'item'),
#    (0.021678936, 'owner'),
#    (0.01958634, 'work'),
#    (0.017521072, 'backlog'),
#    (0.01317071, 'scrum'),
#    (0.009192602, 'complete'),
#    (0.0089412145, 'meeting'),
#    (0.008766336, 'estimate'),
#    (0.008232958, 'change'),
#    (0.008183291, 'time'),
#    (0.0071014035, 'review'),
#    (0.006054105, 'make'),
#    (0.005683348, 'member'),
#    (0.005472907, 'take'),
#    (0.0053547006, 'business'),
#    (0.005280067, 'priority'),
#    (0.005266159, 'new')],
#   -0.5484051877061243),
#  ([(0.037691005, 'end'),
#    (0.032514125, 'book'),
#    (0.02902482, 'shopping'),
#    (0.028950574, 'dayremaine'),
#    (0.027844401, 'work'),
#    (0.02482459, 'team'),
#    (0.022724142, 'buyer_place'),
#    (0.021572514, 'sprint'),
#    (0.01965485, 'estimate'),
#    (0.017169163, 'processing'),
#    (0.017056393, 'improve_transaction'),
#    (0.016658803, 'remain'),
#    (0.015894672, 'much'),
#    (0.013442835, 'webpage'),
#    (0.010160816, 'figure'),
#    (0.010130285, 'show'),
#    (0.010078954, 'term'),
#    (0.0086523965, 'backlog'),
#    (0.0077020596, 'day'),
#    (0.0076733995, 'goal')],
#   -0.6691488957950198),
#  ([(0.049435426, 'team'),
#    (0.03553628, 'scrummaster'),
#    (0.032805324, 'product'),
#    (0.029671198, 'manager'),
#    (0.027620893, 'role'),
#    (0.024585465, 'help'),
#    (0.022550179, 'scrum'),
#    (0.022473125, 'owner'),
#    (0.012302281, 'project'),
#    (0.011614012, 'management'),
#    (0.009849042, 'manage'),
#    (0.009482016, 'change'),
#    (0.009330105, 'success'),
#    (0.009279224, 'individual'),
#    (0.008395151, 'result'),
#    (0.0082080085, 'lead'),
#    (0.008162254, 'development'),
#    (0.00798128, 'practice'),
#    (0.0074437866, 'example'),
#    (0.0071699047, 'make')],
#   -0.6950868728879698),
#  ([(0.0018443778, 'product'),
#    (0.0015682479, 'sprint'),
#    (0.0015126102, 'team'),
#    (0.0014063877, 'item'),
#    (0.0013721853, 'owner'),
#    (0.0011842526, 'part'),
#    (0.0011207826, 'backlog'),
#    (0.0011033363, 'work'),
#    (0.0010549633, 'definition'),
#    (0.0010461551, 'do'),
#    (0.0010308147, 'scrum'),
#    (0.0010186512, 'potentially_shippable'),
#    (0.0010073137, 'goal'),
#    (0.0010057776, 'priority'),
#    (0.0009989546, 'need'),
#    (0.0009903724, 'deliver'),
#    (0.000989605, 'delay'),
#    (0.0009865025, 'meeting'),
#    (0.0009828166, 'development'),
#    (0.0009798576, 'end')],
#   -0.7189300695148969),
#  ([(0.0042010434, 'team'),
#    (0.003547926, 'product'),
#    (0.0020221856, 'sprint'),
#    (0.0019740476, 'item'),
#    (0.0018711189, 'work'),
#    (0.0016766703, 'scrum'),
#    (0.0016743232, 'owner'),
#    (0.0016360662, 'backlog'),
#    (0.0014551395, 'manager'),
#    (0.0013640099, 'development'),
#    (0.0013607742, 'role'),
#    (0.001342164, 'complete'),
#    (0.0013075914, 'feature'),
#    (0.0012992978, 'estimate'),
#    (0.0012503902, 'make'),
#    (0.0012393318, 'end'),
#    (0.0012234781, 'help'),
#    (0.0012221563, 'project'),
#    (0.0012083714, 'time'),
#    (0.0012042925, 'take')],
#   -0.7324525878988184),
#  ([(0.06082766, 'product'),
#    (0.047528025, 'sprint'),
#    (0.044974394, 'team'),
#    (0.034317188, 'owner'),
#    (0.031536337, 'part'),
#    (0.021208396, 'item'),
#    (0.021102633, 'potentially_shippable'),
#    (0.018465262, 'definition'),
#    (0.016028242, 'backlog'),
#    (0.013263184, 'goal'),
#    (0.013241745, 'do'),
#    (0.010750136, 'work'),
#    (0.010710903, 'meeting'),
#    (0.0106613785, 'priority'),
#    (0.010655741, 'deliver'),
#    (0.010635232, 'need'),
#    (0.010627671, 'increment'),
#    (0.0106188655, 'delay'),
#    (0.0080366675, 'high'),
#    (0.008030839, 'start')],
#   -0.7637025116529311),
#  ([(0.028378546, 'sprint'),
#    (0.024652282, 'feedback'),
#    (0.021266537, 'development'),
#    (0.019959755, 'cross_functional'),
#    (0.019446919, 'end'),
#    (0.014809446, 'iterative'),
#    (0.014229053, 'team'),
#    (0.013006382, 'cycle'),
#    (0.012043013, 'short'),
#    (0.010188524, 'loop'),
#    (0.010154766, 'concept'),
#    (0.010144954, 'next'),
#    (0.010144101, 'lack'),
#    (0.010050728, 'delay'),
#    (0.009442511, 'test'),
#    (0.009427315, 'improve'),
#    (0.009397606, 'increase'),
#    (0.009237869, 'traditional'),
#    (0.008963138, 'framework'),
#    (0.00856756, 'real')],
#   -1.003583253731261),
#  ([(0.053531796, 'product'),
#    (0.038075358, 'backlog'),
#    (0.026589673, 'estimate'),
#    (0.026312655, 'new'),
#    (0.024888415, 'item'),
#    (0.02130831, 'sprint'),
#    (0.015210515, 'processing'),
#    (0.015138803, 'figure'),
#    (0.014031988, 'performance'),
#    (0.013614395, 'wiki'),
#    (0.012879528, 'speed'),
#    (0.012118244, 'order'),
#    (0.010813102, 'exist'),
#    (0.009936145, 'book'),
#    (0.009768329, 'user'),
#    (0.009768171, 'defect'),
#    (0.009759252, 'system'),
#    (0.00973859, 'shopper'),
#    (0.0097221015, 'card'),
#    (0.009721397, 'investigate')],
#   -1.0628053190551043),
#  ([(0.04246045, 'sprint'),
#    (0.037893888, 'product'),
#    (0.037467998, 'release'),
#    (0.018614396, 'new'),
#    (0.017267792, 'refinement'),
#    (0.01654247, 'initial'),
#    (0.015539437, 'planning'),
#    (0.015398552, 'estimate'),
#    (0.01341248, 'backlog'),
#    (0.011787011, 'practice'),
#    (0.010917607, 'development'),
#    (0.010424309, 'case'),
#    (0.01006662, 'team'),
#    (0.009626561, 'scrum'),
#    (0.00920605, 'establish'),
#    (0.009194825, 'perfection'),
#    (0.009181642, 'vision'),
#    (0.008989843, 'continuous'),
#    (0.008966913, 'prepare'),
#    (0.008613608, 'consider')],
#   -1.0900650357889625),
#  ([(0.0010895747, 'team'),
#    (0.0010533873, 'product'),
#    (0.0009925591, 'sprint'),
#    (0.0009919908, 'item'),
#    (0.0009777746, 'owner'),
#    (0.00096398505, 'work'),
#    (0.0009479574, 'backlog'),
#    (0.00093923055, 'end'),
#    (0.00093204505, 'estimate'),
#    (0.00093108596, 'scrum'),
#    (0.00092643045, 'priority'),
#    (0.0009185258, 'book'),
#    (0.0009183697, 'business'),
#    (0.0009179251, 'complete'),
#    (0.0009175758, 'make'),
#    (0.00091607583, 'member'),
#    (0.0009154963, 'value'),
#    (0.00091512245, 'time'),
#    (0.0009149807, 'much'),
#    (0.000913148, 'shopping')],
#   -1.2130006736168726),
#  ([(0.0009951408, 'team'),
#    (0.0009582703, 'scrum'),
#    (0.00092843425, 'make'),
#    (0.000917439, 'sprint'),
#    (0.00091544236, 'owner'),
#    (0.0009118332, 'manager'),
#    (0.0009103631, 'product'),
#    (0.00091006956, 'scrummaster'),
#    (0.0009080099, 'change'),
#    (0.0009066947, 'help'),
#    (0.0009059387, 'require'),
#    (0.00090565236, 'practice'),
#    (0.0009040812, 'time'),
#    (0.0009036595, 'meeting'),
#    (0.0009035915, 'benefit'),
#    (0.00090286066, 'experience'),
#    (0.0009025078, 'visible'),
#    (0.0009019195, 'example'),
#    (0.0009016827, 'common'),
#    (0.00090061314, 'member')],
#   -1.3164224275141427),
#  ([(0.04671592, 'team'),
#    (0.03324589, 'scrum'),
#    (0.0281953, 'task'),
#    (0.027001616, 'sprint'),
#    (0.014319998, 'make'),
#    (0.014159134, 'learn'),
#    (0.0108163385, 'work'),
#    (0.009610932, 'practice'),
#    (0.009602329, 'experience'),
#    (0.009541474, 'rare'),
#    (0.009414523, 'time'),
#    (0.009277055, 'member'),
#    (0.0072510852, 'require'),
#    (0.007230883, 'visible'),
#    (0.007226856, 'good'),
#    (0.007217862, 'benefit'),
#    (0.007211161, 'well'),
#    (0.0072002574, 'skill'),
#    (0.0071879756, 'necessary'),
#    (0.0071867104, 'forecast')],
#   -2.0461908412928453),
#  ([(0.043394096, 'scrum'),
#    (0.03373828, 'agile'),
#    (0.028892359, 'primer'),
#    (0.02416305, 'scale'),
#    (0.019669821, 'team'),
#    (0.019429212, 'development'),
#    (0.019400934, 'lean'),
#    (0.01462954, 'large'),
#    (0.014625043, 'material'),
#    (0.01462269, 'description'),
#    (0.014615013, 'additional'),
#    (0.009942709, 'management'),
#    (0.00993734, 'project'),
#    (0.009906184, 'practice'),
#    (0.00989929, 'succeed'),
#    (0.009897198, 'many'),
#    (0.009882761, 'find'),
#    (0.009856396, 'think'),
#    (0.00985286, 'online'),
#    (0.0098434165, 'available')],
#   -2.539991484109251),
#  ([(0.0016991815, 'team'),
#    (0.0016197748, 'product'),
#    (0.001578956, 'scrum'),
#    (0.0012141748, 'agile'),
#    (0.0011959533, 'sprint'),
#    (0.0011796086, 'primer'),
#    (0.0011240223, 'owner'),
#    (0.0010877954, 'development'),
#    (0.0010832231, 'detail'),
#    (0.0010690273, 'work'),
#    (0.0010638275, 'find'),
#    (0.0010550133, 'available'),
#    (0.0010530535, 'many'),
#    (0.0010414788, 'backlog'),
#    (0.0010275756, 'item'),
#    (0.0010275362, 'take'),
#    (0.0010115083, 'scale'),
#    (0.0010110489, 'practice'),
#    (0.0010065304, 'management'),
#    (0.0010044948, 'advise')],
#   -3.981630450222912)]

# %%
# Find the topic with the highest coherence score
top_top_word = []
for topic_words, coherence_score in top_topics:
    # Get the word with the highest probability in the topic
    top_word = max(topic_words, key=lambda x: x[0])
    top_top_word.append(top_word)
    # Print the top word and its probability
    print("Top Word in Topic:")
    print("Word:", top_word[1])
    print("Coherence Score:", top_word[0])
    print()
print(top_top_word)
# Out:
# Top Word in Topic:
# Word: product
# Coherence Score: 0.0027059228
#
# Top Word in Topic:
# Word: product
# Coherence Score: 0.053440496
#
# Top Word in Topic:
# Word: end
# Coherence Score: 0.037691005
#
# Top Word in Topic:
# Word: team
# Coherence Score: 0.049435426
#
# Top Word in Topic:
# Word: product
# Coherence Score: 0.0018443778
#
# Top Word in Topic:
# Word: team
# Coherence Score: 0.0042010434
#
# Top Word in Topic:
# Word: product
# Coherence Score: 0.06082766
#
# Top Word in Topic:
# Word: sprint
# Coherence Score: 0.028378546
#
# Top Word in Topic:
# Word: product
# Coherence Score: 0.053531796
#
# Top Word in Topic:
# Word: sprint
# Coherence Score: 0.04246045
#
# Top Word in Topic:
# Word: team
# Coherence Score: 0.0010895747
#
# Top Word in Topic:
# Word: team
# Coherence Score: 0.0009951408
#
# Top Word in Topic:
# Word: team
# Coherence Score: 0.04671592
#
# Top Word in Topic:
# Word: scrum
# Coherence Score: 0.043394096
#
# Top Word in Topic:
# Word: team
# Coherence Score: 0.0016991815
#
# [(0.0027059228, 'product'), (0.053440496, 'product'), (0.037691005, 'end'), (0.049435426, 'team'), (0.0018443778, 'product'), (0.0042010434, 'team'), (0.06082766, 'product'), (0.028378546, 'sprint'), (0.053531796, 'product'), (0.04246045, 'sprint'), (0.0010895747, 'team'), (0.0009951408, 'team'), (0.04671592, 'team'), (0.043394096, 'scrum'), (0.0016991815, 'team')]

# %%
top_subjects = []

# for topic_words, coherence_score in top_topics:
#     top_word = max(topic_words, key=lambda x: x[0])[1]
#     top_subjects.append((top_word, coherence_score))

# Sort the subjects based on coherence scores
sorted_subjects = sorted(top_topwords, key=lambda x: x[0], reverse=True)

# Get the top 3 subjects
top_3_subjects = sorted_subjects[:5]

# Print the top 3 subjects
for i, (subject, coherence_score) in enumerate(top_3_subjects, 1):
    print(f"Top Subject {i}:")
    print("Subject:", subject)
    print("Coherence Score:", coherence_score)
    print()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 8
#       1 top_subjects = []
#       3 # for topic_words, coherence_score in top_topics:
#       4 #     top_word = max(topic_words, key=lambda x: x[0])[1]
#       5 #     top_subjects.append((top_word, coherence_score))
#       6
#       7 # Sort the subjects based on coherence scores
# ----> 8 sorted_subjects = sorted(top_topwords, key=lambda x: x[0], reverse=True)
#      10 # Get the top 3 subjects
#      11 top_3_subjects = sorted_subjects[:5]
#
# NameError: name 'top_topwords' is not defined
